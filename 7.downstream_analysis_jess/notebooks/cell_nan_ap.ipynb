# %%
# Imports
import pathlib
import pandas as pd
import numpy as np
import polars as pl

import black
import jupyter_black

jupyter_black.load(
    lab=False,
    line_length=79,
    verbosity="DEBUG",
    target_version=black.TargetVersion.PY310,
)

import warnings
warnings.filterwarnings("ignore")
# Out:
# DEBUG:jupyter_black:config: {'line_length': 79, 'target_versions': {<TargetVersion.PY310: 10>}}

# %%
# Define all paths and files
map_data_dir = pathlib.Path("/dgx1nas1/storage/data/jess/varchamp/sc_data/map_data/").resolve(strict=True)
bl_path = pathlib.Path(f'{map_data_dir}/bl_map_data.parquet')

# %%
# Read in data
bl = pl.read_parquet(bl_path)

feat_col = [i for i in bl.columns if "Metadata_" not in i] 
feat_col = [i for i in feat_col if i not in ['n_pos_pairs', 'n_total_pairs', 'average_precision']]

# %%
# Count the number of NaNs per cell
nd_cells = bl.select(feat_col).to_numpy()
nan_mask = np.isnan(nd_cells)
nan_per_cell = np.sum(nan_mask, axis=1).reshape(-1, 1)

# %%
nan_s = pl.Series("nan_per_cell", nan_per_cell)
bl.insert_column(6, nan_s)

# clearly the NaN number do not match the average precision results
# next to check is the subsetting script
# Out:
# shape: (26_069, 3_233)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ n_pos_pai ┆ … ┆ Nuclei_Te ┆ Nuclei_Te ┆ Nuclei_Te ┆ Nuclei_T │
# │ Plate     ┆ allele    ┆ CellID    ┆ rs        ┆   ┆ xture_Var ┆ xture_Var ┆ xture_Var ┆ exture_V │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ iance_Mit ┆ iance_Mit ┆ iance_Mit ┆ ariance_ │
# │ str       ┆ str       ┆ str       ┆ i64       ┆   ┆ o_5_0…    ┆ o_5_0…    ┆ o_5_0…    ┆ Mito_5_0 │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ …        │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2023-05-2 ┆ FBP1_     ┆ 2023-05-2 ┆ 35        ┆ … ┆ 42.580016 ┆ 35.327662 ┆ 38.009556 ┆ 40.55628 │
# │ 6_B1A1R1_ ┆           ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 3        │
# │ P2T1      ┆           ┆ P2T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3.0_3…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-2 ┆ FBP1_     ┆ 2023-05-2 ┆ 35        ┆ … ┆ 6.528384  ┆ 5.895417  ┆ 6.897715  ┆ 7.054662 │
# │ 6_B1A1R1_ ┆           ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │ P2T1      ┆           ┆ P2T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 4.0_3…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-2 ┆ GFAP_Glu2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 11.931021 ┆ 10.890998 ┆ 10.534774 ┆ 10.43210 │
# │ 6_B1A1R1_ ┆ 05Lys     ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ P2T1      ┆           ┆ P2T1_A02_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 16.0_…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-2 ┆ GFAP_Glu2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 2.155372  ┆ 2.629256  ┆ 2.318919  ┆ 2.332629 │
# │ 6_B1A1R1_ ┆ 05Lys     ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │ P2T1      ┆           ┆ P2T1_A02_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 17.0_…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-2 ┆ GFAP_Glu2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 1.42666   ┆ 1.347653  ┆ 1.348762  ┆ 1.519655 │
# │ 6_B1A1R1_ ┆ 05Lys     ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │ P2T1      ┆           ┆ P2T1_A02_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 17.0_…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2023-05-3 ┆ ZMYND10_A ┆ 2023-05-3 ┆ 15        ┆ … ┆ 2.816072  ┆ 2.596785  ┆ 3.077508  ┆ 2.39139  │
# │ 0_B1A1R1_ ┆ rg340Gln  ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │ P4T4      ┆           ┆ P4T4_P19_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3405.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-3 ┆ ZMYND10_A ┆ 2023-05-3 ┆ 15        ┆ … ┆ 6.61035   ┆ 6.874659  ┆ 6.801506  ┆ 6.831889 │
# │ 0_B1A1R1_ ┆ rg340Gln  ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │ P4T4      ┆           ┆ P4T4_P19_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3406.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-3 ┆ ZMYND10_A ┆ 2023-05-3 ┆ 15        ┆ … ┆ 36.909544 ┆ 33.408075 ┆ 35.593136 ┆ 37.09710 │
# │ 0_B1A1R1_ ┆ rg340Gln  ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 1        │
# │ P4T4      ┆           ┆ P4T4_P19_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3408.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-3 ┆ ZMYND10_A ┆ 2023-05-3 ┆ 15        ┆ … ┆ 18.977547 ┆ 19.352069 ┆ 19.939829 ┆ 18.69047 │
# │ 0_B1A1R1_ ┆ rg340Gln  ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ P4T4      ┆           ┆ P4T4_P19_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3411.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-05-3 ┆ UBQLN2_Pr ┆ 2023-05-3 ┆ 11        ┆ … ┆ 12.457018 ┆ 12.724852 ┆ 11.858793 ┆ 13.78724 │
# │ 0_B1A1R1_ ┆ o506Thr   ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ P4T4      ┆           ┆ P4T4_P13_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3357.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
