# %%
# Imports
import pathlib
import pandas as pd
import numpy as np
import polars as pl

import black
import jupyter_black

jupyter_black.load(
    lab=False,
    line_length=79,
    verbosity="DEBUG",
    target_version=black.TargetVersion.PY310,
)

import warnings
warnings.filterwarnings("ignore")
# Out:
# DEBUG:jupyter_black:config: {'line_length': 79, 'target_versions': {<TargetVersion.PY310: 10>}}

# %%
# Define all paths and files
map_data_dir = pathlib.Path("/dgx1nas1/storage/data/jess/varchamp/sc_data/map_data/").resolve(strict=True)
bl_path = pathlib.Path(f'{map_data_dir}/norm_map_data.parquet')

# %%
# Read in data
bl = pl.read_parquet(bl_path)

feat_col = [i for i in bl.columns if "Metadata_" not in i] 
feat_col = [i for i in feat_col if i not in ['n_pos_pairs', 'n_total_pairs', 'average_precision']]

# %%
# Count the number of NaNs per cell
nd_cells = bl.select(feat_col).to_numpy()
nan_mask = np.isnan(nd_cells)
nan_per_cell = np.sum(nan_mask, axis=1).reshape(-1, 1)

# %%
nan_s = pl.Series("nan_per_cell", nan_per_cell)
bl.insert_column(6, nan_s)
# Out:
# shape: (26_069, 3_016)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ n_pos_pai ┆ … ┆ Nuclei_Te ┆ Nuclei_Te ┆ Nuclei_Te ┆ Nuclei_T │
# │ allele    ┆ Plate     ┆ CellID    ┆ rs        ┆   ┆ xture_Var ┆ xture_Var ┆ xture_Var ┆ exture_V │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ iance_Mit ┆ iance_Mit ┆ iance_Mit ┆ ariance_ │
# │ str       ┆ str       ┆ str       ┆ i64       ┆   ┆ o_5_0…    ┆ o_5_0…    ┆ o_5_0…    ┆ Mito_5_0 │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ ---       ┆ ---       ┆ …        │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ SGCA_     ┆ 2023-05-3 ┆ 2023-05-3 ┆ 15        ┆ … ┆ 1.23819   ┆ 1.209079  ┆ 1.216536  ┆ 1.236908 │
# │           ┆ 0_B1A1R1_ ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P4T1      ┆ P4T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3.0_3…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SGCA_     ┆ 2023-05-3 ┆ 2023-05-3 ┆ 15        ┆ … ┆ 1.079297  ┆ 1.078707  ┆ 1.060516  ┆ 1.016406 │
# │           ┆ 0_B1A1R1_ ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P4T1      ┆ P4T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3.0_7…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SGCA_     ┆ 2023-05-3 ┆ 2023-05-3 ┆ 15        ┆ … ┆ 1.954574  ┆ 2.040526  ┆ 1.852038  ┆ 2.012003 │
# │           ┆ 0_B1A1R1_ ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P4T1      ┆ P4T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 9.0_3…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SGCA_     ┆ 2023-05-3 ┆ 2023-05-3 ┆ 15        ┆ … ┆ 1.382724  ┆ 1.429929  ┆ 1.439068  ┆ 1.435422 │
# │           ┆ 0_B1A1R1_ ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P4T1      ┆ P4T1_A01_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 9.0_6…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ STXBP1_As ┆ 2023-05-3 ┆ 2023-05-3 ┆ 15        ┆ … ┆ -1.020993 ┆ -1.009458 ┆ -1.023596 ┆ -1.00327 │
# │ p207Asn   ┆ 0_B1A1R1_ ┆ 0_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │           ┆ P4T1      ┆ P4T1_A02_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 10.0_…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ LITAF_Ile ┆ 2023-05-2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 0.49176   ┆ 0.46472   ┆ 0.503338  ┆ 0.511525 │
# │ 92Val     ┆ 6_B1A1R1_ ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P2T1      ┆ P2T1_P22_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3438.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ KRT4_     ┆ 2023-05-2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 0.115382  ┆ 0.008488  ┆ 0.015411  ┆ 0.114334 │
# │           ┆ 6_B1A1R1_ ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P2T1      ┆ P2T1_P23_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3439.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ MCEE_     ┆ 2023-05-2 ┆ 2023-05-2 ┆ 31        ┆ … ┆ 0.331601  ┆ 0.331561  ┆ 0.330076  ┆ 0.324953 │
# │           ┆ 6_B1A1R1_ ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P2T1      ┆ P2T1_P24_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3453.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ KRT4_     ┆ 2023-05-2 ┆ 2023-05-2 ┆ 15        ┆ … ┆ 0.566926  ┆ 0.562563  ┆ 0.568956  ┆ 0.59957  │
# │           ┆ 6_B1A1R1_ ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P2T1      ┆ P2T1_P23_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3439.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ MCEE_     ┆ 2023-05-2 ┆ 2023-05-2 ┆ 31        ┆ … ┆ 0.331601  ┆ 0.331561  ┆ 0.330076  ┆ 0.324953 │
# │           ┆ 6_B1A1R1_ ┆ 6_B1A1R1_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ P2T1      ┆ P2T1_P24_ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3451.…    ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
